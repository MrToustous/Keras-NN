# %%
import models
from data_loader import *

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
google = ticker('GOOGL')

# %%
google.get_data()

# %%
dataset = google.create_dataset(look_back = 7)

# %%
google.dataset
# Out:
#               X(t-1)    X(t-2)    X(t-3)    X(t-4)    X(t-5)    X(t-6)  \
# 2010-01-14 -0.005758 -0.017842 -0.001513  0.013243 -0.023555 -0.025532
# 2010-01-15  0.004690 -0.005758 -0.017842 -0.001513  0.013243 -0.023555
# 2010-01-19 -0.016840  0.004690 -0.005758 -0.017842 -0.001513  0.013243
# 2010-01-20  0.013052 -0.016840  0.004690 -0.005758 -0.017842 -0.001513
# 2010-01-21 -0.012346  0.013052 -0.016840  0.004690 -0.005758 -0.017842
# 2010-01-22  0.004418 -0.012346  0.013052 -0.016840  0.004690 -0.005758
# 2010-01-25 -0.058216  0.004418 -0.012346  0.013052 -0.016840  0.004690
# 2010-01-26 -0.018367 -0.058216  0.004418 -0.012346  0.013052 -0.016840
# 2010-01-27  0.004471 -0.018367 -0.058216  0.004418 -0.012346  0.013052
# 2010-01-28 -0.000590  0.004471 -0.018367 -0.058216  0.004418 -0.012346
# 2010-01-29 -0.014512 -0.000590  0.004471 -0.018367 -0.058216  0.004418
# 2010-02-01 -0.008175 -0.014512 -0.000590  0.004471 -0.018367 -0.058216
# ...
